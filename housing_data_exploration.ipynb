# %%
import pandas as pd
import seaborn as sns


housing = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/housing.csv')
housing_reduced = housing.sample(1000)

housing
# Out:
#                id             date  bedrooms  bathrooms  sqft_living
# 0      1565930130  20141104T000000         4       3.25         3760  \
# 1      3279000420  20150115T000000         3       1.75         1460
# 2       194000575  20141014T000000         4       1.00         1340
# 3      2115510160  20141208T000000         3       1.75         1440
# 4      7522500005  20140815T000000         2       1.50         1780
# ...           ...              ...       ...        ...          ...
# 19995  5272200045  20141113T000000         3       1.50         1000
# 19996  9578500790  20141111T000000         3       2.50         3087
# 19997  7202350480  20140930T000000         3       2.50         2120
# 19998  1723049033  20140620T000000         1       0.75          380
# 19999  6147650280  20150325T000000         4       2.50         3130
#
#        sqft_lot  floors  waterfront  view  condition  ...  sqft_above
# ...

# %% [markdown]
# # Plotting Homes by Location and Price

# %%
housing_reduced.plot(
    x="long", y="lat", kind="scatter", c="price", colormap="YlOrRd"
)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
import plotly.express as px

df = housing
fig = px.scatter_geo(housing_reduced, lat='lat', lon='long', hover_name="price", color="price")
fig.update_layout(title='World map', title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="bf2a80d8-dacc-454d-ba0d-8f6bb06612b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf2a80d8-dacc-454d-ba0d-8f6bb06612b2")) {                    Plotly.newPlot(                        "bf2a80d8-dacc-454d-ba0d-8f6bb06612b2",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>lat=%{lat}<br>long=%{lon}<br>price=%{marker.color}<extra></extra>","hovertext":[472217.0,260000.0,180000.0,225000.0,379900.0,509990.0,130000.0,137900.0,340000.0,450000.0,300000.0,546200.0,597750.0,248000.0,435000.0,440000.0,250000.0,175000.0,1285000.0,500000.0,519000.0,620000.0,306000.0,290000.0,560000.0,1697000.0,870000.0,357000.0,529500.0,213000.0,542500.0,542000.0,375000.0,920000.0,643500.0,1500000.0,275
# ...

# %% [markdown]
# # Exploring Other Data

# %%
sns.histplot(data=housing, x="yr_built")
# Out:
# <Axes: xlabel='yr_built', ylabel='Count'>

# %%
sns.histplot(data=housing, x="yr_renovated")
# Out:
# <Axes: xlabel='yr_renovated', ylabel='Count'>

# %% [markdown]
# ### Renovation Years

# %%
renovated_houses = housing[housing['yr_renovated'] != 0]

sns.scatterplot(
    data=renovated_houses,
    x="yr_renovated",
    y="yr_built",
)
# Out:
# <Axes: xlabel='yr_renovated', ylabel='yr_built'>

# %% [markdown]
# ### Living Square Footage vs. Price

# %%
sns.lmplot(
    data=housing_reduced,
    x='sqft_living',
    y='price',
)
